# %%
import datasets

sward = datasets.load_from_disk('datasets/SwaRD/')
ARID = datasets.load_from_disk('datasets/ARID/')
UOCSSR = datasets.load_from_disk('datasets/UOCSSR/')

# %%
print(sward.info.license)
# Out:
#     # SwaRD: A Composite Dataset for Software Requirements Research --- Licensing and Attribution
#
#
# ## **License and Usage Notice**
#
# The **SwaRD** dataset is an identified collection that aggregates data from multiple publicly available sources, each governed by its own license terms. While all source datasets are available for research and academic purposes, they are not uniformly licensed, and therefore
#
#
# **SwaRD is not distributed under a unified license**.
#
# ## **Important Notice to Users:**
#
# • Each constituent dataset retains its original license as specified in its source.<br>
# • Users are responsible for reviewing and complying with the license terms associated with each dataset before reuse or redistribution.<br>
# • Attribution to original authors and repositories is provided in the *Dataset Attributions by License* section.<br>
#
# ...
